# %% [markdown]
# # IO and data
#
# **Table of contents**
# 1. Hello world
# 2. Mad libs
# 3. Arithmetic operators
# 4. BMI calculator
# 5. Coin change calculator

# %% [markdown]
# ## 1. Hello world
#
# Change the text in quotes below and press the ▶️ button above (or hit `ctrl`+`enter` / `cmd`+`enter`) to run the code.

# %%
print("Hello, World!")

# %% [markdown]
# Here's a program that greets the user.

# %%
name = "Terence"  # CHANGE THE TEXT to your own name
print(f"Hello, {name}!")  # CHANGE THE TEXT to another greeting
# Out:
# Hello, Terence!

# %% [markdown]
# ## Mad libs
#
# | Term      | Explanation                          | Examples                                   |
# |-----------|--------------------------------------|--------------------------------------------|
# | Adjective | Describes a quality or attribute     | Happy, Brave, Beautiful                    |
# | Adverb    | Describes how an action is performed | Gracefully, Swiftly, Carefully             |
# | Noun      | Person, place, thing, or idea        | Cat, Book, Friendship                      |
# | Place     | Location or area                     | Garden, Beach, Mountains                   |
# | Verb      | Action or state of being             | Dance, Sing, Explore                       |
#
# Write your mad libs program below.

# %%
# Prompt the user to enter a noun, verb, an adjective, and adverb, and a place below!
# Code goes here

# Turn this into an f-string involving all the above inputs that you have defined!
story = "Once upon a time, in a PLACE far, far away, there was a ADJECTIVE NOUN who loved to VERB ADVERB."

# Display the Mad Libs story
print("\nYour Mad Libs Story:")
print(story)

# %% [markdown]
# ## Arithmetic operators
#
# | Math         | Python  |
# | ------------ | ------- |
# | $a + b$      | `a + b` |
# | $a - b$      | `a - b` |
# | $a \times b$ | `a * b` |
# | $a \div b$   | `a / b` |

# %% [markdown]
# ## BMI calculator
# Below is some code which calculates BMI of the user. However, it has an error. Can you guess why is that so?
#
# After finding out the answer, you can change the code in the cell below.

# %%
weight = input("Enter your weight: ")
height = input("Enter your height: ")

bmi = weight / (height * height) # Calculating BMI

print(f"Your BMI is: {bmi}")

# %%
# Example program that demonstrates arithmetic operations in python
# Run this program!! Changing the inputs are highly encouraged!! Try to output 90 with just 5, 6 and 3!!
a = 1
b = 3
print(1 + b)
print(a - b)
print(a * 4)
print(1 / 4)
print((a + b) * 6 / 89)

# %% [markdown]
# ## Coin change
#
# Write your coin change program below!

# %% [markdown]
# ## Extra Excercise: Temperature - Converting Fahrenheit to Celsius [OPTIONAL]
#
# You are developing a weather application for a global audience. One essential feature of this application is the ability to convert temperatures between Fahrenheit and Celsius. Your task is to create a Python program that converts temperatures from Fahrenheit to Celsius.
#
# Conversion between Fahrenheit and Celsius:
# - 32 degrees Fahrenheit is 0 degrees Celsius.
# - 41 degrees Fahrenheit is 5 degrees Celsius.
# - 50 degrees Fahrenheit is 10 degrees Celsius.
#
# Notice a pattern between Fahrenheit and Celsius?
#
# Write a program to ask the user for an input of temperature in Fahrenheit, convert the temperature to celsius and display the temperature in celsius.

# %% [markdown]
# <details>
#     <summary>Hint</summary>
#     For every 9 degrees increase in Farenheit, there is a 5 degree increase Celsius.
# </details>

# %% [markdown]
# \
# \
# Download the next lesson notebook (*Conditionals*) **[here](https://github.com/artofcode-sg/lesson-materials/blob/main/notebooks/%5B2%5D%20Conditionals.ipynb)**!
